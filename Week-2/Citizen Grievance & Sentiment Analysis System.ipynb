# %%
##Week-1 tasks
import pandas as pd

df = pd.read_csv("C:\\Users\\UVESH SHAIKH\\OneDrive\\Pictures\\Desktop\\DS&ML\\Project-1\\clipdataset.csv")
print(df.columns)
# Out:
# C:\Temp\ipykernel_25940\3557705156.py:3: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\UVESH SHAIKH\\OneDrive\\Pictures\\Desktop\\DS&ML\\Project-1\\clipdataset.csv")
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location', 'Zip Codes', 'Community Districts',
#        'Borough Boundaries', 'City Council Districts', 'Police Precincts'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unique Key             Created Date              Closed Date Agency  \
# 0    45052849  2019-12-01T01:42:46.000                      NaN   NYPD
# 1    45051451  2019-12-01T01:24:47.000                      NaN   NYPD
# 2    45049327  2019-12-01T01:04:16.000                      NaN   NYPD
# 3    45053522  2019-12-01T00:48:01.000                      NaN   NYPD
# 4    45050836  2019-11-30T23:22:48.000  2019-12-01T01:27:32.000   NYPD
#
#                        Agency Name       Complaint Type  \
# 0  New York City Police Department   Noise - Commercial
# 1  New York City Police Department  Noise - Residential
# 2  New York City Police Department      Illegal Parking
# 3  New York City Police Department  Noise - Residential
# 4  New York City Police Department      Illegal Parking
#
#                      Descriptor     Location Type  Incident Zip  \
# 0              Loud Music/Party  Store/Commercial       10002.0
# 1              Banging/Pounding               NaN       10452.0
# 2               Blocked Hydrant   Street/Sidewalk       11374.0
# 3              Loud Music/Party               NaN       11435.0
# 4  Commercial Overnight Parking   Street/Sidewalk       10307.0
#
#         Incident Address  ... Road Ramp Bridge Highway Segment   Latitude  \
# 0   151 RIVINGTON STREET  ...       NaN                    NaN  40.719247
# 1   1675 GRAND CONCOURSE  ...       NaN                    NaN  40.844402
# 2  65-41 SAUNDERS STREET  ...       NaN                    NaN  40.727562
# 3              90 AVENUE  ...       NaN                    NaN  40.701215
# 4           CRAIG AVENUE  ...       NaN                    NaN  40.511790
#
#    Longitude                                           Location Zip Codes  \
# 0 -73.985646  {'longitude': '-73.98564578325737', 'latitude'...       NaN
# 1 -73.911526  {'longitude': '-73.91152601056106', 'latitude'...       NaN
# 2 -73.858060  {'longitude': '-73.85805982707932', 'latitude'...       NaN
# 3 -73.813363  {'longitude': '-73.81336256667298', 'latitude'...       NaN
# 4 -74.245311  {'longitude': '-74.24531109376724', 'latitude'...       NaN
#
#   Community Districts Borough Boundaries City Council Districts  \
# 0                 NaN                NaN                    NaN
# 1                 NaN                NaN                    NaN
# 2                 NaN                NaN                    NaN
# 3                 NaN                NaN                    NaN
# 4                 NaN                NaN                    NaN
#
#   Police Precincts
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220106 entries, 0 to 220105
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      220106 non-null  int64
#  1   Created Date                    220106 non-null  object
#  2   Closed Date                     197300 non-null  object
#  3   Agency                          220106 non-null  object
#  4   Agency Name                     220106 non-null  object
#  5   Complaint Type                  220106 non-null  object
#  6   Descriptor                      214666 non-null  object
#  7   Location Type                   146571 non-null  object
#  8   Incident Zip                    214180 non-null  float64
#  9   Incident Address                208416 non-null  object
#  10  Street Name                     208416 non-null  object
#  11  Cross Street 1                  182153 non-null  object
#  12  Cross Street 2                  182151 non-null  object
#  13  Intersection Street 1           162539 non-null  object
#  14  Intersection Street 2           162588 non-null  object
#  15  Address Type                    72238 non-null   object
#  16  City                            199318 non-null  object
#  17  Landmark                        136570 non-null  object
#  18  Facility Type                   5288 non-null    object
#  19  Status                          220106 non-null  object
#  20  Due Date                        0 non-null       float64
#  21  Resolution Description          193920 non-null  object
#  22  Resolution Action Updated Date  204754 non-null  object
#  23  Community Board                 220106 non-null  object
#  24  BBL                             183577 non-null  float64
#  25  Borough                         220106 non-null  object
#  26  X Coordinate (State Plane)      212268 non-null  float64
#  27  Y Coordinate (State Plane)      212268 non-null  float64
#  28  Open Data Channel Type          220106 non-null  object
#  29  Park Facility Name              219827 non-null  object
#  30  Park Borough                    220106 non-null  object
#  31  Vehicle Type                    45 non-null      object
#  32  Taxi Company Borough            296 non-null     object
#  33  Taxi Pick Up Location           12442 non-null   object
#  34  Bridge Highway Name             0 non-null       float64
#  35  Bridge Highway Direction        341 non-null     object
#  36  Road Ramp                       341 non-null     object
#  37  Bridge Highway Segment          341 non-null     object
#  38  Latitude                        212268 non-null  float64
#  39  Longitude                       212268 non-null  float64
#  40  Location                        212268 non-null  object
#  41  Zip Codes                       211081 non-null  float64
#  42  Community Districts             212141 non-null  float64
#  43  Borough Boundaries              212141 non-null  float64
#  44  City Council Districts          212141 non-null  float64
#  45  Police Precincts                212141 non-null  float64
# dtypes: float64(13), int64(1), object(32)
# memory usage: 77.2+ MB

# %%
df.describe()
# Out:
#          Unique Key   Incident Zip  Due Date           BBL  \
# count  2.201060e+05  214180.000000       0.0  1.835770e+05
# mean   4.388083e+07   10837.142917       NaN  2.804980e+09
# std    9.107564e+04     552.381497       NaN  1.205943e+09
# min    4.385998e+07   10000.000000       NaN  0.000000e+00
# 25%    4.386571e+07   10310.000000       NaN  2.027040e+09
# 50%    4.387072e+07   11207.000000       NaN  3.031770e+09
# 75%    4.387511e+07   11237.000000       NaN  4.020030e+09
# max    4.505496e+07   11697.000000       NaN  5.270001e+09
#
#        X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# count                2.122680e+05               212268.000000
# mean                 1.005452e+06               203808.870470
# std                  2.322258e+04                29510.182274
# min                  9.146200e+05               121496.000000
# 25%                  9.914850e+05               183851.000000
# 50%                  1.003372e+06               202363.000000
# 75%                  1.018688e+06               223309.000000
# max                  1.067173e+06               271876.000000
#
#        Bridge Highway Name       Latitude      Longitude      Zip Codes  \
# count                  0.0  212268.000000  212268.000000  211081.000000
# mean                   NaN      40.726029     -73.923474   14838.282702
# std                    NaN       0.080999       0.083751    3728.749288
# min                    NaN      40.499903     -74.250417   10090.000000
# 25%                    NaN      40.671275     -73.973946   12074.000000
# 50%                    NaN      40.721959     -73.930905   13827.000000
# 75%                    NaN      40.779501     -73.875707   17214.000000
# max                    NaN      40.912869     -73.700758   24894.000000
#
#        Community Districts  Borough Boundaries  City Council Districts  \
# count        212141.000000       212141.000000           212141.000000
# mean             36.919483            3.113368               27.578695
# std              21.030885            1.145643               14.266718
# min               1.000000            1.000000                1.000000
# 25%              18.000000            2.000000               15.000000
# 50%              39.000000            3.000000               28.000000
# 75%              56.000000            4.000000               39.000000
# max              71.000000            5.000000               51.000000
#
#        Police Precincts
# count     212141.000000
# mean          42.279295
# std           21.700529
# min            1.000000
# 25%           26.000000
# 50%           43.000000
# 75%           62.000000
# max           77.000000

# %%
df.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                        22806
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          5440
# Location Type                      73535
# Incident Zip                        5926
# Incident Address                   11690
# Street Name                        11690
# Cross Street 1                     37953
# Cross Street 2                     37955
# Intersection Street 1              57567
# Intersection Street 2              57518
# Address Type                      147868
# City                               20788
# Landmark                           83536
# Facility Type                     214818
# Status                                 0
# Due Date                          220106
# Resolution Description             26186
# Resolution Action Updated Date     15352
# Community Board                        0
# BBL                                36529
# Borough                                0
# X Coordinate (State Plane)          7838
# Y Coordinate (State Plane)          7838
# Open Data Channel Type                 0
# Park Facility Name                   279
# Park Borough                           0
# Vehicle Type                      220061
# Taxi Company Borough              219810
# Taxi Pick Up Location             207664
# Bridge Highway Name               220106
# Bridge Highway Direction          219765
# Road Ramp                         219765
# Bridge Highway Segment            219765
# Latitude                            7838
# Longitude                           7838
# Location                            7838
# Zip Codes                           9025
# Community Districts                 7965
# Borough Boundaries                  7965
# City Council Districts              7965
# Police Precincts                    7965
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location', 'Zip Codes', 'Community Districts',
#        'Borough Boundaries', 'City Council Districts', 'Police Precincts'],
#       dtype='object')

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\UVESH
# [nltk_data]     SHAIKH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\UVESH
# [nltk_data]     SHAIKH\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['text'] = df['Complaint Type'] + " " + df['Descriptor']
df['text'] = df['Complaint Type'].fillna('') + " " + df['Descriptor'].fillna('')

df['clean_text'] = df['text'].str.lower()

df['clean_text'] = df['clean_text'].apply(lambda x: re.sub(r'[^a-zA-Z ]', '', x))

df['clean_text'] = df['clean_text'].apply(
    lambda x: " ".join([word for word in x.split() if word not in stop_words])
)
df[['text', 'clean_text']].head()
# Out:
#                                            text  \
# 0           Noise - Commercial Loud Music/Party
# 1          Noise - Residential Banging/Pounding
# 2               Illegal Parking Blocked Hydrant
# 3          Noise - Residential Loud Music/Party
# 4  Illegal Parking Commercial Overnight Parking
#
#                                      clean_text
# 0              noise commercial loud musicparty
# 1             noise residential bangingpounding
# 2               illegal parking blocked hydrant
# 3             noise residential loud musicparty
# 4  illegal parking commercial overnight parking

# %%
print(df[['text', 'clean_text']])
# Out:
#                                                      text  \
# 0                     Noise - Commercial Loud Music/Party
# 1                    Noise - Residential Banging/Pounding
# 2                         Illegal Parking Blocked Hydrant
# 3                    Noise - Residential Loud Music/Party
# 4            Illegal Parking Commercial Overnight Parking
# ...                                                   ...
# 220101               Noise - Residential Loud Music/Party
# 220102                    Illegal Parking Blocked Hydrant
# 220103                   New Tree Request For One Address
# 220104                    Illegal Parking Blocked Hydrant
# 220105  Building/Use Illegal Conversion Of Residential...
#
#                                                clean_text
# 0                        noise commercial loud musicparty
# 1                       noise residential bangingpounding
# 2                         illegal parking blocked hydrant
# 3                       noise residential loud musicparty
# 4            illegal parking commercial overnight parking
# ...                                                   ...
# 220101                  noise residential loud musicparty
# 220102                    illegal parking blocked hydrant
# 220103                       new tree request one address
# 220104                    illegal parking blocked hydrant
# 220105  buildinguse illegal conversion residential bui...
#
# [220106 rows x 2 columns]

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\uvesh shaikh\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\uvesh shaikh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud


text_data = " ".join(df['clean_text'])

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common Complaints WordCloud")
plt.show()

# %%
from collections import Counter

words = " ".join(df['clean_text']).split()
word_freq = Counter(words)

print(word_freq.most_common(10))
# Out:
# [('noise', 57087), ('parking', 36216), ('loud', 34368), ('condition', 30692), ('musicparty', 28860), ('blocked', 28736), ('illegal', 28486), ('residential', 24977), ('complaint', 24235), ('vehicle', 22096)]

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(ngram_range=(2,2))
X = vectorizer.fit_transform(df['clean_text'])

sum_words = X.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)

print(words_freq[:10])
# Out:
# [('loud musicparty', np.int64(28860)), ('illegal parking', np.int64(24702)), ('noise residential', np.int64(20815)), ('blocked driveway', np.int64(16638)), ('residential loud', np.int64(15399)), ('noise streetsidewalk', np.int64(14892)), ('streetsidewalk loud', np.int64(14892)), ('driveway access', np.int64(11821)), ('parking blocked', np.int64(11131)), ('complaint driver', np.int64(10051))]

# %%
import matplotlib.pyplot as plt

# count top complaints
top_complaints = df['Complaint Type'].value_counts().head(10)

# plot
top_complaints.plot(kind='bar')

plt.title("Top 10 Complaint Types")
plt.xlabel("Complaint Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

df['Complaint Type'].value_counts().head(5).plot(kind='bar')

plt.title("Most Common Complaints")
plt.xlabel("Complaint Type")
plt.ylabel("Number of Complaints")

plt.show()

# %%
##week-2 task
X = df['clean_text']
y = df['Complaint Type']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000) ##Convert Text → Numbers

X_vectorized = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split##Train-Test Split

X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized, y, test_size=0.2, random_state=42
)

# %%
##Train Model (Logistic Regression)
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9999545681704602

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
# C:\Users\UVESH SHAIKH\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                          precision    recall  f1-score   support
#
#                               APPLIANCE       1.00      1.00      1.00       175
#                       Abandoned Vehicle       1.00      1.00      1.00      1014
#                             Air Quality       1.00      1.00      1.00       144
#             Animal Facility - No Permit       1.00      1.00      1.00         5
#                        Animal in a Park       1.00      1.00      1.00        62
#                            Animal-Abuse       1.00      1.00      1.00       310
#                                Asbestos       1.00      1.00      1.00        37
#                        BEST/Site Safety       1.00      1.00      1.00         6
#                     Bike Rack Condition       1.00      1.00      1.00         7
#               Bike/Roller/Skate Chronic       1.00      1.00      1.00        10
#                        Blocked Driveway       1.00      1.00      1.00      3280
#                                 Boilers       1.00      1.00      1.00        10
#                    Broken Parking Meter       1.00      1.00      1.00       269
#                            Building/Use       1.00      1.00      1.00       410
#              Bus Stop Shelter Complaint       1.00      1.00      1.00        36
#              Bus Stop Shelter Placement       1.00      1.00      1.00        12
#                      Consumer Complaint       1.00      1.00      1.00       341
#                     Cranes and Derricks       1.00      1.00      1.00         4
#                          Curb Condition       1.00      1.00      1.00       150
#                    DEP Street Condition       1.00      1.00      1.00        23
#                             DOOR/WINDOW       1.00      1.00      1.00       282
#                            Damaged Tree       1.00      1.00      1.00       506
#                                Day Care       1.00      1.00      1.00         9
#                         Dead/Dying Tree       1.00      1.00      1.00       319
#                        Derelict Bicycle       1.00      1.00      1.00        26
#                       Derelict Vehicles       1.00      1.00      1.00       793
#                        Dirty Conditions       1.00      1.00      1.00       604
#                                Drinking       1.00      1.00      1.00        59
#                          Drinking Water       1.00      1.00      1.00        18
#                           Drug Activity       1.00      1.00      1.00       173
#                                ELECTRIC       1.00      1.00      1.00       181
#                                ELEVATOR       1.00      1.00      1.00        17
#                              Electrical       1.00      1.00      1.00        57
#                                Elevator       1.00      1.00      1.00       329
#           Emergency Response Team (ERT)       1.00      1.00      1.00        90
#                   Executive Inspections       1.00      1.00      1.00         3
#                         FLOORING/STAIRS       1.00      1.00      1.00        63
#                           Ferry Inquiry       1.00      1.00      1.00        10
#                      Food Establishment       1.00      1.00      1.00       214
#                          Food Poisoning       1.00      1.00      1.00        83
#              For Hire Vehicle Complaint       1.00      1.00      1.00      1693
#                 For Hire Vehicle Report       0.00      0.00      0.00         1
#                          Found Property       1.00      1.00      1.00         7
#                                 GENERAL       1.00      1.00      1.00       230
#           General Construction/Plumbing       1.00      1.00      1.00       965
#                                Graffiti       1.00      1.00      1.00         7
#                    Green Taxi Complaint       1.00      1.00      1.00         8
#                          HEAT/HOT WATER       1.00      1.00      1.00       651
#                    Harboring Bees/Wasps       1.00      1.00      1.00        13
#                     Hazardous Materials       1.00      1.00      1.00       101
#                       Highway Condition       1.00      1.00      1.00        67
#                     Homeless Encampment       1.00      1.00      1.00       235
#              Homeless Person Assistance       1.00      1.00      1.00       801
#                       Illegal Fireworks       1.00      1.00      1.00         9
#                         Illegal Parking       1.00      1.00      1.00      4832
#                     Illegal Tree Damage       1.00      1.00      1.00        62
#                      Indoor Air Quality       1.00      1.00      1.00        49
#                           Indoor Sewage       1.00      1.00      1.00        38
#                        Industrial Waste       1.00      1.00      1.00        24
#     Investigations and Discipline (IAD)       1.00      1.00      1.00        16
#                                    Lead       1.00      1.00      1.00       393
#                           Lost Property       1.00      1.00      1.00       415
#                 Maintenance or Facility       1.00      1.00      1.00       430
#       Missed Collection (All Materials)       1.00      1.00      1.00       456
#                      Mobile Food Vendor       1.00      1.00      1.00        41
#                                    Mold       1.00      1.00      1.00        11
#                              Mosquitoes       1.00      1.00      1.00        30
#                        New Tree Request       1.00      1.00      1.00       322
#                                   Noise       1.00      1.00      1.00       924
#                      Noise - Commercial       1.00      1.00      1.00       744
#                      Noise - Helicopter       1.00      1.00      1.00       117
#                Noise - House of Worship       1.00      1.00      1.00         8
#                            Noise - Park       1.00      1.00      1.00       218
#                     Noise - Residential       1.00      1.00      1.00      4204
#                 Noise - Street/Sidewalk       1.00      1.00      1.00      3005
#                         Noise - Vehicle       1.00      1.00      1.00      1369
#             Non-Emergency Police Matter       1.00      1.00      1.00       380
#                    Non-Residential Heat       0.00      0.00      0.00         1
#                       Other Enforcement       1.00      1.00      1.00        25
#                 Overgrown Tree/Branches       1.00      1.00      1.00       362
#                           PAINT/PLASTER       1.00      1.00      1.00       255
#                                PLUMBING       1.00      1.00      1.00       355
#                             Panhandling       1.00      1.00      1.00        14
#                                   Plant       1.00      1.00      1.00         5
#                                Plumbing       1.00      1.00      1.00        48
#                              Poison Ivy       1.00      1.00      1.00         6
#               Public Payphone Complaint       1.00      1.00      1.00         7
#                   Recycling Enforcement       1.00      1.00      1.00        28
#                                  Rodent       1.00      1.00      1.00       860
#           Root/Sewer/Sidewalk Condition       1.00      1.00      1.00       481
#                                  SAFETY       1.00      1.00      1.00       100
#                    Sanitation Condition       1.00      1.00      1.00        61
#                      School Maintenance       1.00      1.00      1.00        43
#                                   Sewer       1.00      1.00      1.00       446
#                      Sidewalk Condition       1.00      1.00      1.00       945
#                                 Smoking       1.00      1.00      1.00        64
# Special Projects Inspection Team (SPIT)       1.00      1.00      1.00       134
#                          Standing Water       1.00      1.00      1.00        60
#                        Street Condition       1.00      1.00      1.00      1423
#                  Street Light Condition       1.00      1.00      1.00      1024
#                   Street Sign - Damaged       1.00      1.00      1.00       152
#                  Street Sign - Dangling       1.00      1.00      1.00        27
#                   Street Sign - Missing       1.00      1.00      1.00       104
#                               Tattooing       1.00      1.00      1.00         7
#                          Taxi Complaint       1.00      1.00      1.00       299
#                         Taxi Compliment       1.00      1.00      1.00         6
#                             Taxi Report       0.99      1.00      0.99        68
#                                 Traffic       1.00      1.00      1.00       116
#                Traffic Signal Condition       1.00      1.00      1.00       641
#                    UNSANITARY CONDITION       1.00      1.00      1.00       938
#                           Unleashed Dog       1.00      1.00      1.00        26
#          Unsanitary Animal Pvt Property       1.00      1.00      1.00        46
#             Unsanitary Pigeon Condition       1.00      1.00      1.00        14
#                     Urinating in Public       1.00      1.00      1.00        17
#                                 Vending       1.00      1.00      1.00       115
#                 Violation of Park Rules       1.00      1.00      1.00        87
#                              WATER LEAK       1.00      1.00      1.00       377
#                      Water Conservation       1.00      1.00      1.00        55
#                           Water Quality       1.00      1.00      1.00        33
#                            Water System       1.00      1.00      1.00      1124
#                            Window Guard       1.00      1.00      1.00         6
#
#                                accuracy                           1.00     44022
#                               macro avg       0.98      0.98      0.98     44022
#                            weighted avg       1.00      1.00      1.00     44022
# C:\Users\UVESH SHAIKH\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\UVESH SHAIKH\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.colorbar()
plt.show()

# %%
sample = ["water leakage in my street"]

sample_vec = vectorizer.transform(sample)

print(model.predict(sample_vec))
# Out:
# ['Street Condition']
